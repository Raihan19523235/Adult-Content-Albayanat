# %%
import numpy as np
import pandas as pd 
from keras import initializers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, Dropout, LSTM, Bidirectional
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from nltk.tokenize import sent_tokenize
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score
import seaborn as sns
from keras.models import load_model

# %%
data = pd.read_excel("data/label/combineSSL1.xlsx")
data.replace('', np.nan, inplace=True)
data.dropna(inplace=True) # memastikan tidak ada nilai yang kosong
dewasa = data.loc[data['label'] == 1, 'tweet'].copy().reset_index(drop=True)
bukan = data.loc[data['label'] == 0, 'tweet'].copy().reset_index(drop=True)
print("Total Data :", len(data))
print("Bukan Dewasa :", len(bukan))
print("Dewasa :", len(dewasa))

plt.figure(figsize=(10,8))
sns.countplot(x='label', data=data)
plt.show()
# Out:
# Total Data : 54338
# Bukan Dewasa : 27192
# Dewasa : 27146

# %%
# Splitting Data
text = data['tweet'].values
label = data['label'].values
data_train, data_test, label_train, label_test = train_test_split(text, label, test_size=0.33, random_state=42)
data_train, data_val, label_train, label_val = train_test_split(data_train, label_train, test_size= 0.33, random_state=42)

# %%
# Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)

vocab = max([len(tokenizer.word_index)]) + 1 # kamus kata 
maxlen = max([len(i.split()) for i in text]) # panjang input sequence
batch_size = 128 # penentuan jumlah sample yang ditraining pada tiap epoch
num_epochs = 5 # banyak iterasi pada saat training model 
initializer = initializers.RandomUniform(minval=-0.05, maxval=0.05, seed=2)

# %%
#Data Train
X_train = tokenizer.texts_to_sequences(data_train)
X_train = pad_sequences(X_train, maxlen=maxlen)
Y_train = to_categorical(label_train, num_classes = 2)

#Data Test
X_test = tokenizer.texts_to_sequences(data_test)
X_test = pad_sequences(X_test, maxlen=maxlen)
Y_test = to_categorical(label_test, num_classes = 2)

#Data Validation
X_val = tokenizer.texts_to_sequences(data_val)
X_val = pad_sequences(X_val, maxlen=maxlen)
Y_val = to_categorical(label_val, num_classes = 2)

# %%
def get_model1(X, Y):
    model = Sequential() 
    model.add(Embedding(input_dim = vocab, output_dim = 128, input_length = maxlen, embeddings_initializer = initializer))
    model.add(Bidirectional(LSTM(128, recurrent_initializer = initializer, kernel_initializer = initializer)))
    model.add(Dense(2, activation='sigmoid', kernel_initializer = initializer)) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    
    return model

def get_model2(X, Y):
    model = Sequential() 
    model.add(Embedding(input_dim = vocab, output_dim = 128, input_length = maxlen, embeddings_initializer = initializer))
    model.add(Bidirectional(LSTM(128, recurrent_initializer = initializer, kernel_initializer = initializer, return_sequences=True)))
    model.add(Bidirectional(LSTM(128)))
    model.add(Dense(2, activation='sigmoid', kernel_initializer = initializer)) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    
    return model

def get_model3(X, Y):
    model = Sequential() 
    model.add(Embedding(input_dim = vocab, output_dim = 128, input_length = maxlen, embeddings_initializer = initializer))
    model.add(Dropout(0.9))
    model.add(Bidirectional(LSTM(128, recurrent_initializer = initializer, kernel_initializer = initializer)))
    model.add(Dropout(0.4))
    model.add(Dense(2, activation='sigmoid', kernel_initializer = initializer)) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    
    return model

def get_model4(X, Y):
    model = Sequential() 
    model.add(Embedding(input_dim = vocab, output_dim = 128, input_length = maxlen, embeddings_initializer = initializer))
    model.add(Dropout(0.9))
    model.add(Bidirectional(LSTM(128, recurrent_initializer = initializer, kernel_initializer = initializer, return_sequences=True)))
    model.add(Dropout(0.5))
    model.add(Bidirectional(LSTM(128)))
    model.add(Dropout(0.4))
    model.add(Dense(2, activation='sigmoid', kernel_initializer = initializer)) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    
    return model

def plot_history(histories, key='loss'):
    plt.figure(figsize=(16,10))

    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

        plt.xlabel('Epochs')
        plt.ylabel(key.replace('_',' ').title())
        plt.legend()
        plt.xlim([0,max(history.epoch)])
        
def evaluation(model, X, Y):
    # Predict the values
    Y_pred = model.predict(X)
    Y_pred_class = np.argmax(Y_pred, axis=1)
    Y_act = Y
    # accuracy
    accuracy = accuracy_score(Y_act, Y_pred_class)
    print("Accuracy: %.2f" % (accuracy*100), "%")
    # precision
    precision = precision_score(Y_act, Y_pred_class)
    print("Precision: %.2f" % (precision*100), "%")
    # recall
    recall = recall_score(Y_act, Y_pred_class)
    print("Recall: %.2f" % (recall*100), "%")
    
    return Y_act, Y_pred_class

def conf_matrix(Y_act, Y_pred):
    # compute the confusion matrix
    confusion_mtx = confusion_matrix(Y_act, Y_pred)
    plt.figure(figsize=(10,8))
    sns.heatmap(confusion_mtx, annot=True, fmt="d");
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
# Model 1

# %%
model1 = get_model1(X_train, Y_train)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 58, 32)            1325248
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 64)                16640
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 1,342,018
# Trainable params: 1,342,018
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training model
history1 = model1.fit(X_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/20
# 191/191 [==============================] - 14s 56ms/step - loss: 0.6140 - accuracy: 0.6222 - val_loss: 0.1914 - val_accuracy: 0.9471
# Epoch 2/20
# 191/191 [==============================] - 11s 59ms/step - loss: 0.1218 - accuracy: 0.9728 - val_loss: 0.0746 - val_accuracy: 0.9829
# Epoch 3/20
# 191/191 [==============================] - 11s 55ms/step - loss: 0.0424 - accuracy: 0.9911 - val_loss: 0.0701 - val_accuracy: 0.9817
# Epoch 4/20
# 191/191 [==============================] - 10s 53ms/step - loss: 0.0233 - accuracy: 0.9956 - val_loss: 0.0711 - val_accuracy: 0.9821
# Epoch 5/20
# 191/191 [==============================] - 11s 56ms/step - loss: 0.0162 - accuracy: 0.9968 - val_loss: 0.0735 - val_accuracy: 0.9804
# Epoch 6/20
# 191/191 [==============================] - 10s 55ms/step - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.0928 - val_accuracy: 0.9761
# Epoch 7/20
# 191/191 [==============================] - 10s 53ms/step - loss: 0.0128 - accuracy: 0.9975 - val_loss: 0.0926 - val_accuracy: 0.9761
# Epoch 8/20
# 191/191 [==============================] - 11s 58ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.0809 - val_accuracy: 0.9805
# Epoch 9/20
# 191/191 [==============================] - 10s 54ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.0889 - val_accuracy: 0.9808
# Epoch 10/20
# 191/191 [==============================] - 10s 54ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0950 - val_accuracy: 0.9805
# Epoch 11/20
# 191/191 [==============================] - 11s 56ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.0944 - val_accuracy: 0.9806
# Epoch 12/20
# 191/191 [==============================] - 10s 54ms/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 0.0961 - val_accuracy: 0.9799
# Epoch 13/20
# 191/191 [==============================] - 10s 54ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.1007 - val_accuracy: 0.9791
# Epoch 14/20
# 191/191 [==============================] - 12s 65ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.1028 - val_accuracy: 0.9793
# Epoch 15/20
# 191/191 [==============================] - 12s 63ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.1053 - val_accuracy: 0.9783
# Epoch 16/20
# 191/191 [==============================] - 12s 62ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.1087 - val_accuracy: 0.9778
# Epoch 17/20
# 191/191 [==============================] - 10s 54ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.1101 - val_accuracy: 0.9775
# Epoch 18/20
# 191/191 [==============================] - 10s 55ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.1048 - val_accuracy: 0.9776
# Epoch 19/20
# 191/191 [==============================] - 11s 55ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.1089 - val_accuracy: 0.9770
# Epoch 20/20
# 191/191 [==============================] - 11s 60ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1169 - val_accuracy: 0.9775

# %%
plot_history([('M1-SkenarioBiLSTM06', history1)])

# %%
# Evaluasi 1

# %%
print("Evaluasi Data Test")
Y_act, Y_pred = evaluation(model1, X_test, label_test)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Test
# Accuracy: 97.61 %
# Precision: 98.50 %
# Recall: 96.59 %
# [0.4625210165977478, 0.09365732967853546, 0.03804098069667816, 0.022418856620788574, 0.016920071095228195, 0.01290208287537098, 0.008349784649908543, 0.007235425524413586, 0.006202030926942825, 0.0054441955871880054, 0.005174863152205944, 0.011988310143351555, 0.007767834234982729, 0.004274210426956415, 0.0035556722432374954, 0.005654887296259403, 0.005051054991781712, 0.003425230970606208, 0.00308050075545907, 0.002726097824051976, 0.002778522204607725, 0.0025772396475076675, 0.0026211687363684177, 0.0024297432973980904, 0.002321138046681881, 0.002413330366834998, 0.003630587365478277, 0.0035630769561976194, 0.0023242535535246134, 0.0019706592429429293, 0.002097850665450096, 0.0019567266572266817, 0.001988281961530447, 0.0019135690527036786, 0.0019970827270299196, 0.0019300824496895075, 0.002100258134305477, 0.0018139294115826488, 0.0018957903375849128, 0.0018493221141397953, 0.0031759014818817377, 0.003006197977811098, 0.0020357263274490833, 0.001832652254961431, 0.0016635868232697248, 0.00170284288469702, 0.0016841304022818804, 0.0018555255373939872, 0.0016814167611300945, 0.0015578210586681962]

# %%
print("Evaluasi Data Train")
Y_act, Y_pred = evaluation(model1, X_train, label_train)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Train
# Accuracy: 99.95 %
# Precision: 99.99 %
# Recall: 99.91 %

# %%
# Model 2

# %%
model2 = get_model2(X_train, Y_train)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 58, 128)           5300992
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               263168
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 5,564,674
# Trainable params: 5,564,674
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training model
history2 = model2.fit(X_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/50
# 191/191 [==============================] - 50s 251ms/step - loss: 0.4884 - accuracy: 0.7270 - val_loss: 0.0708 - val_accuracy: 0.9806
# Epoch 2/50
# 191/191 [==============================] - 51s 266ms/step - loss: 0.0420 - accuracy: 0.9887 - val_loss: 0.0636 - val_accuracy: 0.9821
# Epoch 3/50
# 191/191 [==============================] - 47s 246ms/step - loss: 0.0202 - accuracy: 0.9948 - val_loss: 0.0669 - val_accuracy: 0.9829
# Epoch 4/50
# 191/191 [==============================] - 49s 258ms/step - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.0744 - val_accuracy: 0.9822
# Epoch 5/50
# 191/191 [==============================] - 48s 250ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.0806 - val_accuracy: 0.9816
# Epoch 6/50
# 191/191 [==============================] - 48s 250ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.0844 - val_accuracy: 0.9813
# Epoch 7/50
# 191/191 [==============================] - 48s 252ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0959 - val_accuracy: 0.9790
# Epoch 8/50
# 191/191 [==============================] - 48s 252ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0889 - val_accuracy: 0.9808
# Epoch 9/50
# 191/191 [==============================] - 48s 252ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0947 - val_accuracy: 0.9788
# Epoch 10/50
# 191/191 [==============================] - 47s 248ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.1002 - val_accuracy: 0.9792
# Epoch 11/50
# 191/191 [==============================] - 48s 249ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0962 - val_accuracy: 0.9795
# Epoch 12/50
# 191/191 [==============================] - 48s 249ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0977 - val_accuracy: 0.9805
# Epoch 13/50
# Epoch 34/50
# 191/191 [==============================] - 49s 255ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.1409 - val_accuracy: 0.9795
# Epoch 35/50
# 191/191 [==============================] - 49s 255ms/step - loss: 9.9174e-04 - accuracy: 0.9996 - val_loss: 0.1550 - val_accuracy: 0.9768
# Epoch 36/50
# 191/191 [==============================] - 49s 254ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.1533 - val_accuracy: 0.9805
# Epoch 37/50
# 191/191 [==============================] - 49s 256ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.1433 - val_accuracy: 0.9750
# Epoch 38/50
# 191/191 [==============================] - 49s 258ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.1336 - val_accuracy: 0.9755
# Epoch 39/50
# 191/191 [==============================] - 53s 279ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1327 - val_accuracy: 0.9752
# Epoch 40/50
# 191/191 [==============================] - 50s 262ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.1399 - val_accuracy: 0.9808
# Epoch 41/50
# 191/191 [==============================] - 49s 257ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1360 - val_accuracy: 0.9791
# Epoch 42/50
# 191/191 [==============================] - 49s 256ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.1874 - val_accuracy: 0.9689
# Epoch 43/50
# 191/191 [==============================] - 49s 258ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1467 - val_accuracy: 0.9782
# Epoch 44/50
# 191/191 [==============================] - 49s 257ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1518 - val_accuracy: 0.9798
# Epoch 45/50
# 191/191 [==============================] - 49s 256ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.1502 - val_accuracy: 0.9798
# Epoch 46/50
# 191/191 [==============================] - 49s 255ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.1596 - val_accuracy: 0.9789
# Epoch 47/50
# 191/191 [==============================] - 48s 254ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.1553 - val_accuracy: 0.9782
# Epoch 48/50
# 191/191 [==============================] - 49s 255ms/step - loss: 9.3538e-04 - accuracy: 0.9996 - val_loss: 0.1591 - val_accuracy: 0.9781
# Epoch 49/50
# 191/191 [==============================] - 49s 254ms/step - loss: 8.3102e-04 - accuracy: 0.9997 - val_loss: 0.1608 - val_accuracy: 0.9785
# Epoch 50/50
# 191/191 [==============================] - 50s 260ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.1673 - val_accuracy: 0.9783

# %%
plot_history([('M2-SkenarioBiLSTM06', history2)])

# %%
# Evaluasi 2

# %%
print("Evaluasi Data Test")
Y_act, Y_pred = evaluation(model2, X_test, label_test)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Test
# Accuracy: 98.01 %
# Precision: 98.37 %
# Recall: 97.57 %

# %%
print("Evaluasi Data Train")
Y_act, Y_pred = evaluation(model2, X_train, label_train)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Train
# Accuracy: 99.95 %
# Precision: 99.98 %
# Recall: 99.92 %

# %%
# Model 3

# %%
model3 = get_model3(X_train, Y_train)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 58, 32)            1325248
# _________________________________________________________________
# dropout (Dropout)            (None, 58, 32)            0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 64)                16640
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 1,342,018
# Trainable params: 1,342,018
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training model
history3 = model3.fit(X_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/50
# 191/191 [==============================] - 13s 52ms/step - loss: 0.6621 - accuracy: 0.5813 - val_loss: 0.3252 - val_accuracy: 0.8764
# Epoch 2/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.3101 - accuracy: 0.8804 - val_loss: 0.1503 - val_accuracy: 0.9552
# Epoch 3/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.1892 - accuracy: 0.9327 - val_loss: 0.1031 - val_accuracy: 0.9717
# Epoch 4/50
# 191/191 [==============================] - 9s 47ms/step - loss: 0.1470 - accuracy: 0.9522 - val_loss: 0.0783 - val_accuracy: 0.9780
# Epoch 5/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.1285 - accuracy: 0.9580 - val_loss: 0.0715 - val_accuracy: 0.9804
# Epoch 6/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.1154 - accuracy: 0.9604 - val_loss: 0.0672 - val_accuracy: 0.9819
# Epoch 7/50
# 191/191 [==============================] - 10s 51ms/step - loss: 0.1108 - accuracy: 0.9623 - val_loss: 0.0650 - val_accuracy: 0.9826
# Epoch 8/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0979 - accuracy: 0.9670 - val_loss: 0.0689 - val_accuracy: 0.9819
# Epoch 9/50
# 191/191 [==============================] - 9s 47ms/step - loss: 0.0839 - accuracy: 0.9728 - val_loss: 0.0648 - val_accuracy: 0.9815
# Epoch 10/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0810 - accuracy: 0.9736 - val_loss: 0.0644 - val_accuracy: 0.9828
# Epoch 11/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0767 - accuracy: 0.9754 - val_loss: 0.0710 - val_accuracy: 0.9791
# Epoch 12/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0695 - accuracy: 0.9765 - val_loss: 0.0685 - val_accuracy: 0.9814
# Epoch 13/50
# 191/191 [==============================] - 9s 47ms/step - loss: 0.0647 - accuracy: 0.9786 - val_loss: 0.0742 - val_accuracy: 0.9793
# Epoch 14/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0649 - accuracy: 0.9773 - val_loss: 0.0745 - val_accuracy: 0.9789
# Epoch 15/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0685 - accuracy: 0.9762 - val_loss: 0.0771 - val_accuracy: 0.9774
# Epoch 36/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0353 - accuracy: 0.9885 - val_loss: 0.1043 - val_accuracy: 0.9709
# Epoch 37/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0344 - accuracy: 0.9885 - val_loss: 0.1038 - val_accuracy: 0.9719
# Epoch 38/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0307 - accuracy: 0.9897 - val_loss: 0.1092 - val_accuracy: 0.9703
# Epoch 39/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0396 - accuracy: 0.9870 - val_loss: 0.1133 - val_accuracy: 0.9714
# Epoch 40/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0336 - accuracy: 0.9887 - val_loss: 0.1053 - val_accuracy: 0.9711
# Epoch 41/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0358 - accuracy: 0.9886 - val_loss: 0.1067 - val_accuracy: 0.9695
# Epoch 42/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0343 - accuracy: 0.9890 - val_loss: 0.1095 - val_accuracy: 0.9705
# Epoch 43/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0318 - accuracy: 0.9898 - val_loss: 0.1119 - val_accuracy: 0.9695
# Epoch 44/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0348 - accuracy: 0.9883 - val_loss: 0.1206 - val_accuracy: 0.9690
# Epoch 45/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0379 - accuracy: 0.9885 - val_loss: 0.1090 - val_accuracy: 0.9716
# Epoch 46/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0302 - accuracy: 0.9902 - val_loss: 0.1292 - val_accuracy: 0.9672
# Epoch 47/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0313 - accuracy: 0.9901 - val_loss: 0.1212 - val_accuracy: 0.9692
# Epoch 48/50
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0301 - accuracy: 0.9904 - val_loss: 0.1164 - val_accuracy: 0.9700
# Epoch 49/50
# 191/191 [==============================] - 9s 48ms/step - loss: 0.0314 - accuracy: 0.9891 - val_loss: 0.1151 - val_accuracy: 0.9689
# Epoch 50/50
# 191/191 [==============================] - 9s 50ms/step - loss: 0.0335 - accuracy: 0.9892 - val_loss: 0.1178 - val_accuracy: 0.9687

# %%
plot_history([('M1-SkenarioBiLSTM07', history3)])

# %%
# Evaluasi 3

# %%
print("Evaluasi Data Test")
Y_act, Y_pred = evaluation(model3, X_test, label_test)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Test
# Accuracy: 96.96 %
# Precision: 95.79 %
# Recall: 98.11 %

# %%
print("Evaluasi Data Train")
Y_act, Y_pred = evaluation(model3, X_train, label_train)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Train
# Accuracy: 99.89 %
# Precision: 99.88 %
# Recall: 99.89 %

# %%
# Model 4

# %%
model4 = get_model4(X_train, Y_train)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 58, 128)           5300992
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 58, 128)           0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 256)               263168
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 5,564,674
# Trainable params: 5,564,674
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training model
history4 = model4.fit(X_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/50
# 191/191 [==============================] - 53s 261ms/step - loss: 0.5961 - accuracy: 0.6416 - val_loss: 0.1856 - val_accuracy: 0.9410
# Epoch 2/50
# 191/191 [==============================] - 50s 261ms/step - loss: 0.1669 - accuracy: 0.9446 - val_loss: 0.0705 - val_accuracy: 0.9799
# Epoch 3/50
# 191/191 [==============================] - 50s 263ms/step - loss: 0.0792 - accuracy: 0.9775 - val_loss: 0.0623 - val_accuracy: 0.9829
# Epoch 4/50
# 191/191 [==============================] - 53s 277ms/step - loss: 0.0625 - accuracy: 0.9819 - val_loss: 0.0555 - val_accuracy: 0.9839
# Epoch 5/50
# 191/191 [==============================] - 51s 266ms/step - loss: 0.0537 - accuracy: 0.9831 - val_loss: 0.0532 - val_accuracy: 0.9854
# Epoch 6/50
# 191/191 [==============================] - 51s 266ms/step - loss: 0.0437 - accuracy: 0.9864 - val_loss: 0.0557 - val_accuracy: 0.9843
# Epoch 7/50
# 191/191 [==============================] - 51s 266ms/step - loss: 0.0382 - accuracy: 0.9891 - val_loss: 0.0530 - val_accuracy: 0.9843
# Epoch 8/50
# 191/191 [==============================] - 51s 268ms/step - loss: 0.0335 - accuracy: 0.9898 - val_loss: 0.0549 - val_accuracy: 0.9831
# Epoch 9/50
# 191/191 [==============================] - 51s 267ms/step - loss: 0.0299 - accuracy: 0.9906 - val_loss: 0.0590 - val_accuracy: 0.9831
# Epoch 10/50
# 191/191 [==============================] - 51s 268ms/step - loss: 0.0273 - accuracy: 0.9913 - val_loss: 0.0599 - val_accuracy: 0.9823
# Epoch 11/50
# 191/191 [==============================] - 51s 266ms/step - loss: 0.0244 - accuracy: 0.9933 - val_loss: 0.0614 - val_accuracy: 0.9829
# Epoch 12/50
# 191/191 [==============================] - 51s 267ms/step - loss: 0.0205 - accuracy: 0.9939 - val_loss: 0.0658 - val_accuracy: 0.9804
# Epoch 13/50
# 191/191 [==============================] - 51s 267ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.0678 - val_accuracy: 0.9815
# Epoch 14/50
# 191/191 [==============================] - 51s 267ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 0.0651 - val_accuracy: 0.9819
# Epoch 15/50
# 191/191 [==============================] - 52s 270ms/step - loss: 0.0175 - accuracy: 0.9948 - val_loss: 0.0674 - val_accuracy: 0.9823
# Epoch 16/50
# 191/191 [==============================] - 52s 273ms/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.0656 - val_accuracy: 0.9812
# Epoch 17/50
# 191/191 [==============================] - 50s 262ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0706 - val_accuracy: 0.9819
# Epoch 18/50
# Epoch 38/50
# 191/191 [==============================] - 57s 298ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0941 - val_accuracy: 0.9785
# Epoch 39/50
# 191/191 [==============================] - 55s 290ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0930 - val_accuracy: 0.9766
# Epoch 40/50
# 191/191 [==============================] - 54s 284ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0985 - val_accuracy: 0.9756
# Epoch 41/50
# 191/191 [==============================] - 54s 284ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0983 - val_accuracy: 0.9748
# Epoch 42/50
# 191/191 [==============================] - 59s 308ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.0970 - val_accuracy: 0.9759
# Epoch 43/50
# 191/191 [==============================] - 58s 304ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.1069 - val_accuracy: 0.9752
# Epoch 44/50
# 191/191 [==============================] - 58s 303ms/step - loss: 0.0087 - accuracy: 0.9978 - val_loss: 0.1059 - val_accuracy: 0.9749
# Epoch 45/50
# 191/191 [==============================] - 58s 306ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.1166 - val_accuracy: 0.9744
# Epoch 46/50
# 191/191 [==============================] - 56s 291ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.1030 - val_accuracy: 0.9768
# Epoch 47/50
# 191/191 [==============================] - 55s 288ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.1048 - val_accuracy: 0.9751
# Epoch 48/50
# 191/191 [==============================] - 55s 289ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1199 - val_accuracy: 0.9749
# Epoch 49/50
# 191/191 [==============================] - 55s 288ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.0984 - val_accuracy: 0.9742
# Epoch 50/50
# 191/191 [==============================] - 56s 291ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.1092 - val_accuracy: 0.9729

# %%
plot_history([('M2-SkenarioBiLSTM07', history4)])

# %%
# Evaluasi 4

# %%
print("Evaluasi Data Test")
Y_act, Y_pred = evaluation(model4, X_test, label_test)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Test
# Accuracy: 97.26 %
# Precision: 96.85 %
# Recall: 97.59 %

# %%
print("Evaluasi Data Train")
Y_act, Y_pred = evaluation(model4, X_train, label_train)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Train
# Accuracy: 99.93 %
# Precision: 99.95 %
# Recall: 99.92 %

# %%
# Grafik Keseluruhan

# %%
plot_history([('M1-SkenarioBiLSTM06', history1),
              ('M1-SkenarioBiLSTM07', history3),
              ('M2-SkenarioBiLSTM06', history2),
              ('M2-SkenarioBiLSTM07', history4)])

# %%
# Save Model

# %%
model1.save('model/M1-SkenarioBiLSTM06.h5')
model2.save('model/M2-SkenarioBiLSTM06.h5')
model3.save('model/M1-SkenarioBiLSTM07.h5')
model4.save('model/M2-SkenarioBiLSTM07.h5')
