# %%
import numpy as np
import pandas as pd 
from keras import initializers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, Dropout, LSTM, Bidirectional
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from nltk.tokenize import sent_tokenize
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score
import seaborn as sns

# %%
data = pd.read_excel("data/label/combineSSL1.xlsx")
data.replace('', np.nan, inplace=True)
data.dropna(inplace=True) # memastikan tidak ada nilai yang kosong
dewasa = data.loc[data['label'] == 1, 'tweet'].copy().reset_index(drop=True)
bukan = data.loc[data['label'] == 0, 'tweet'].copy().reset_index(drop=True)
print("Total Data :", len(data))
print("Bukan Dewasa :", len(bukan))
print("Dewasa :", len(dewasa))

plt.figure(figsize=(10,8))
sns.countplot(x='label', data=data)
plt.show()
# Out:
# Total Data : 54338
# Bukan Dewasa : 27192
# Dewasa : 27146

# %%
# Splitting Data
text = data['tweet'].values
label = data['label'].values
data_train, data_test, label_train, label_test = train_test_split(text, label, test_size=0.33, random_state=42)
data_train, data_val, label_train, label_val = train_test_split(data_train, label_train, test_size= 0.33, random_state=42)

# %%
# Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)

vocab = max([len(tokenizer.word_index)]) + 1 # kamus kata 
maxlen = max([len(i.split()) for i in text]) # panjang input sequence
batch_size = 32 # penentuan jumlah sample yang ditraining pada tiap epoch
num_epochs = 20 # banyak iterasi pada saat training model 
initializer = initializers.RandomUniform(minval=-0.05, maxval=0.05, seed=2) # mengatur angka random weigth

# %%
#Data Train
X_train = tokenizer.texts_to_sequences(data_train)
X_train = pad_sequences(X_train, maxlen=maxlen)
Y_train = to_categorical(label_train, num_classes = 2)

#Data Test
X_test = tokenizer.texts_to_sequences(data_test)
X_test = pad_sequences(X_test, maxlen=maxlen)
Y_test = to_categorical(label_test, num_classes = 2)

#Data Validation
X_val = tokenizer.texts_to_sequences(data_val)
X_val = pad_sequences(X_val, maxlen=maxlen)
Y_val = to_categorical(label_val, num_classes = 2)

# %%
def get_model1(X, Y):
    model = Sequential() 
    model.add(Embedding(input_dim = vocab, output_dim = 32, input_length = maxlen, embeddings_initializer = initializer))
    model.add(Bidirectional(LSTM(32, recurrent_initializer = initializer, kernel_initializer = initializer)))
    model.add(Dense(2, activation='sigmoid', kernel_initializer = initializer)) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    
    return model

def get_model2(X, Y):
    model = Sequential() 
    model.add(Embedding(input_dim = vocab, output_dim = 128, input_length = maxlen, embeddings_initializer = initializer))
    model.add(Bidirectional(LSTM(128, recurrent_initializer = initializer, kernel_initializer = initializer)))
    model.add(Dense(2, activation='sigmoid', kernel_initializer = initializer)) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    
    return model

def plot_history(histories, key='loss'):
    plt.figure(figsize=(16,10))

    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

        plt.xlabel('Epochs')
        plt.ylabel(key.replace('_',' ').title())
        plt.legend()
        plt.xlim([0,max(history.epoch)])
        
def evaluation(model, X, Y):
    # Predict the values
    Y_pred = model.predict(X)
    Y_pred_class = np.argmax(Y_pred, axis=1)
    Y_act = Y
    # accuracy
    accuracy = accuracy_score(Y_act, Y_pred_class)
    print("Accuracy: %.2f" % (accuracy*100), "%")
    # precision
    precision = precision_score(Y_act, Y_pred_class)
    print("Precision: %.2f" % (precision*100), "%")
    # recall
    recall = recall_score(Y_act, Y_pred_class)
    print("Recall: %.2f" % (recall*100), "%")
    
    return Y_act, Y_pred_class

def conf_matrix(Y_act, Y_pred):
    # compute the confusion matrix
    confusion_mtx = confusion_matrix(Y_act, Y_pred)
    plt.figure(figsize=(10,8))
    sns.heatmap(confusion_mtx, annot=True, fmt="d");
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %% [markdown]
# # Model 1

# %%
model1 = get_model1(X_train, Y_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 58, 32)            1325248
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                16640
# _________________________________________________________________
# dense (Dense)                (None, 2)                 130
# =================================================================
# Total params: 1,342,018
# Trainable params: 1,342,018
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training model
history1 = model1.fit(X_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/20
# 763/763 [==============================] - 39s 33ms/step - loss: 0.4102 - accuracy: 0.7841 - val_loss: 0.0640 - val_accuracy: 0.9834
# Epoch 2/20
# 763/763 [==============================] - 25s 33ms/step - loss: 0.0395 - accuracy: 0.9895 - val_loss: 0.0583 - val_accuracy: 0.9837
# Epoch 3/20
# 763/763 [==============================] - 26s 34ms/step - loss: 0.0151 - accuracy: 0.9965 - val_loss: 0.0754 - val_accuracy: 0.9798
# Epoch 4/20
# 763/763 [==============================] - 25s 33ms/step - loss: 0.0126 - accuracy: 0.9972 - val_loss: 0.0742 - val_accuracy: 0.9827
# Epoch 5/20
# 763/763 [==============================] - 25s 33ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.0873 - val_accuracy: 0.9801
# Epoch 6/20
# 763/763 [==============================] - 25s 33ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0867 - val_accuracy: 0.9808
# Epoch 7/20
# 763/763 [==============================] - 27s 36ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0884 - val_accuracy: 0.9804
# Epoch 8/20
# 763/763 [==============================] - 25s 33ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.1089 - val_accuracy: 0.9757
# Epoch 9/20
# 763/763 [==============================] - 26s 33ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.1021 - val_accuracy: 0.9792
# Epoch 10/20
# 763/763 [==============================] - 25s 33ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 0.1114 - val_accuracy: 0.9798
# Epoch 11/20
# 763/763 [==============================] - 25s 33ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.1328 - val_accuracy: 0.9732
# Epoch 12/20
# 763/763 [==============================] - 26s 34ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.1138 - val_accuracy: 0.9796
# Epoch 13/20
# 763/763 [==============================] - 26s 34ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.2184 - val_accuracy: 0.9609
# Epoch 14/20
# 763/763 [==============================] - 27s 35ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.1156 - val_accuracy: 0.9786
# Epoch 15/20
# 763/763 [==============================] - 27s 35ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1259 - val_accuracy: 0.9778
# Epoch 16/20
# 763/763 [==============================] - 26s 34ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.1234 - val_accuracy: 0.9770
# Epoch 17/20
# 763/763 [==============================] - 25s 33ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.1248 - val_accuracy: 0.9769
# Epoch 18/20
# 763/763 [==============================] - 23s 30ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1479 - val_accuracy: 0.9776
# Epoch 19/20
# 763/763 [==============================] - 23s 30ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.1259 - val_accuracy: 0.9763
# Epoch 20/20
# 763/763 [==============================] - 23s 30ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.1334 - val_accuracy: 0.9773

# %%
plot_history([('M1-SkenarioBiLSTM01', history1)])

# %% [markdown]
# # Evaluasi 1

# %%
print("Evaluasi Data Test")
Y_act, Y_pred = evaluation(model1, X_test, label_test)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Test
# Accuracy: 97.75 %
# Precision: 97.67 %
# Recall: 97.75 %

# %%
print("Evaluasi Data Train")
Y_act, Y_pred = evaluation(model1, X_train, label_train)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Train
# Accuracy: 99.95 %
# Precision: 100.00 %
# Recall: 99.90 %

# %% [markdown]
# # Model 2

# %%
model2 = get_model2(X_train, Y_train)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 58, 128)           5300992
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               263168
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 5,564,674
# Trainable params: 5,564,674
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training model
history2 = model2.fit(X_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/20
# 763/763 [==============================] - 104s 133ms/step - loss: 0.3060 - accuracy: 0.8528 - val_loss: 0.0631 - val_accuracy: 0.9830
# Epoch 2/20
# 763/763 [==============================] - 96s 126ms/step - loss: 0.0347 - accuracy: 0.9902 - val_loss: 0.0664 - val_accuracy: 0.9819
# Epoch 3/20
# 763/763 [==============================] - 98s 128ms/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.0748 - val_accuracy: 0.9796
# Epoch 4/20
# 763/763 [==============================] - 98s 129ms/step - loss: 0.0078 - accuracy: 0.9982 - val_loss: 0.0739 - val_accuracy: 0.9802
# Epoch 5/20
# 763/763 [==============================] - 97s 127ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0865 - val_accuracy: 0.9829
# Epoch 6/20
# 763/763 [==============================] - 97s 127ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.1049 - val_accuracy: 0.9716
# Epoch 7/20
# 763/763 [==============================] - 98s 129ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.1081 - val_accuracy: 0.9792
# Epoch 8/20
# 763/763 [==============================] - 98s 128ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.1045 - val_accuracy: 0.9784
# Epoch 9/20
# 763/763 [==============================] - 98s 129ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.1117 - val_accuracy: 0.9794
# Epoch 10/20
# 763/763 [==============================] - 98s 128ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1259 - val_accuracy: 0.9769
# Epoch 11/20
# 763/763 [==============================] - 97s 127ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.1167 - val_accuracy: 0.9818
# Epoch 12/20
# 763/763 [==============================] - 97s 127ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1080 - val_accuracy: 0.9795
# Epoch 13/20
# 763/763 [==============================] - 97s 127ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.1123 - val_accuracy: 0.9768
# Epoch 14/20
# 763/763 [==============================] - 97s 127ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.1252 - val_accuracy: 0.9799
# Epoch 15/20
# 763/763 [==============================] - 97s 127ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.1245 - val_accuracy: 0.9761
# Epoch 16/20
# 763/763 [==============================] - 99s 130ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.1047 - val_accuracy: 0.9751
# Epoch 17/20
# 763/763 [==============================] - 97s 127ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.1175 - val_accuracy: 0.9796
# Epoch 18/20
# 763/763 [==============================] - 98s 128ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.1197 - val_accuracy: 0.9793
# Epoch 19/20
# 763/763 [==============================] - 99s 130ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.1221 - val_accuracy: 0.9799
# Epoch 20/20
# 763/763 [==============================] - 100s 131ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.1361 - val_accuracy: 0.9796

# %%
plot_history([('M2-SkenarioBiLSTM01', history2)])

# %% [markdown]
# # Evaluasi 2

# %%
print("Evaluasi Data Test")
Y_act, Y_pred = evaluation(model2, X_test, label_test)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Test
# Accuracy: 98.08 %
# Precision: 97.83 %
# Recall: 98.26 %

# %%
print("Evaluasi Data Train")
Y_act, Y_pred = evaluation(model2, X_train, label_train)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Train
# Accuracy: 99.95 %
# Precision: 99.98 %
# Recall: 99.93 %

# %% [markdown]
# # Grafik Keseluruhan

# %%
plot_history([('M1-SkenarioBiLSTM01', history1),
              ('M2-SkenarioBiLSTM01', history2)])

# %% [markdown]
# # Save Model

# %%
model1.save('model/M1-SkenarioBiLSTM01.h5')
model2.save('model/M2-SkenarioBiLSTM01.h5')
