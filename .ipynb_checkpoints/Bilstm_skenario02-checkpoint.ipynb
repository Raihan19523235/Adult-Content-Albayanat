# %%
import numpy as np
import pandas as pd 
from keras import initializers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, Dropout, LSTM, Bidirectional
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from nltk.tokenize import sent_tokenize
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score
import seaborn as sns

# %%
data = pd.read_excel("data/label/combineSSL1.xlsx")
data.replace('', np.nan, inplace=True)
data.dropna(inplace=True) # memastikan tidak ada nilai yang kosong
dewasa = data.loc[data['label'] == 1, 'tweet'].copy().reset_index(drop=True)
bukan = data.loc[data['label'] == 0, 'tweet'].copy().reset_index(drop=True)
print("Total Data :", len(data))
print("Bukan Dewasa :", len(bukan))
print("Dewasa :", len(dewasa))

plt.figure(figsize=(10,8))
sns.countplot(x='label', data=data)
plt.show()
# Out:
# Total Data : 54338
# Bukan Dewasa : 27192
# Dewasa : 27146

# %%
# Splitting Data
text = data['tweet'].values
label = data['label'].values
data_train, data_test, label_train, label_test = train_test_split(text, label, test_size=0.33, random_state=42)
data_train, data_val, label_train, label_val = train_test_split(data_train, label_train, test_size= 0.33, random_state=42)

# %%
# Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)

vocab = max([len(tokenizer.word_index)]) + 1 # kamus kata 
maxlen = max([len(i.split()) for i in text]) # panjang input sequence
batch_size = 64 # penentuan jumlah sample yang ditraining pada tiap epoch
num_epochs = 20 # banyak iterasi pada saat training model 
initializer = initializers.RandomUniform(minval=-0.05, maxval=0.05, seed=2)

# %%
#Data Train
X_train = tokenizer.texts_to_sequences(data_train)
X_train = pad_sequences(X_train, maxlen=maxlen)
Y_train = to_categorical(label_train, num_classes = 2)

#Data Test
X_test = tokenizer.texts_to_sequences(data_test)
X_test = pad_sequences(X_test, maxlen=maxlen)
Y_test = to_categorical(label_test, num_classes = 2)

#Data Validation
X_val = tokenizer.texts_to_sequences(data_val)
X_val = pad_sequences(X_val, maxlen=maxlen)
Y_val = to_categorical(label_val, num_classes = 2)

# %%
def get_model1(X, Y):
    model = Sequential() 
    model.add(Embedding(input_dim = vocab, output_dim = 32, input_length = maxlen, embeddings_initializer = initializer))
    model.add(Bidirectional(LSTM(32, recurrent_initializer = initializer, kernel_initializer = initializer)))
    model.add(Dense(2, activation='sigmoid', kernel_initializer = initializer)) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    
    return model

def get_model2(X, Y):
    model = Sequential() 
    model.add(Embedding(input_dim = vocab, output_dim = 128, input_length = maxlen, embeddings_initializer = initializer))
    model.add(Bidirectional(LSTM(128, recurrent_initializer = initializer, kernel_initializer = initializer)))
    model.add(Dense(2, activation='sigmoid', kernel_initializer = initializer)) 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    
    return model

def plot_history(histories, key='loss'):
    plt.figure(figsize=(16,10))

    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

        plt.xlabel('Epochs')
        plt.ylabel(key.replace('_',' ').title())
        plt.legend()
        plt.xlim([0,max(history.epoch)])
        
def evaluation(model, X, Y):
    # Predict the values
    Y_pred = model.predict(X)
    Y_pred_class = np.argmax(Y_pred, axis=1)
    Y_act = Y
    # accuracy
    accuracy = accuracy_score(Y_act, Y_pred_class)
    print("Accuracy: %.2f" % (accuracy*100), "%")
    # precision
    precision = precision_score(Y_act, Y_pred_class)
    print("Precision: %.2f" % (precision*100), "%")
    # recall
    recall = recall_score(Y_act, Y_pred_class)
    print("Recall: %.2f" % (recall*100), "%")
    
    return Y_act, Y_pred_class

def conf_matrix(Y_act, Y_pred):
    # compute the confusion matrix
    confusion_mtx = confusion_matrix(Y_act, Y_pred)
    plt.figure(figsize=(10,8))
    sns.heatmap(confusion_mtx, annot=True, fmt="d");
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %% [markdown]
# # Model 1

# %%
model1 = get_model1(X_train, Y_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 58, 32)            1325248
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8320
# _________________________________________________________________
# dense (Dense)                (None, 2)                 66
# =================================================================
# Total params: 1,333,634
# Trainable params: 1,333,634
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training model
history1 = model1.fit(X_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/20
# 382/382 [==============================] - 29s 39ms/step - loss: 0.5074 - accuracy: 0.7280 - val_loss: 0.0785 - val_accuracy: 0.9784
# Epoch 2/20
# 382/382 [==============================] - 15s 38ms/step - loss: 0.0591 - accuracy: 0.9837 - val_loss: 0.0594 - val_accuracy: 0.9850
# Epoch 3/20
# 382/382 [==============================] - 15s 38ms/step - loss: 0.0226 - accuracy: 0.9950 - val_loss: 0.0693 - val_accuracy: 0.9806
# Epoch 4/20
# 382/382 [==============================] - 15s 39ms/step - loss: 0.0136 - accuracy: 0.9969 - val_loss: 0.0674 - val_accuracy: 0.9834
# Epoch 5/20
# 382/382 [==============================] - 15s 38ms/step - loss: 0.0106 - accuracy: 0.9977 - val_loss: 0.0757 - val_accuracy: 0.9809
# Epoch 6/20
# 382/382 [==============================] - 19s 49ms/step - loss: 0.0063 - accuracy: 0.9988 - val_loss: 0.0787 - val_accuracy: 0.9824
# Epoch 7/20
# 382/382 [==============================] - 19s 51ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.0868 - val_accuracy: 0.9815
# Epoch 8/20
# 382/382 [==============================] - 19s 51ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0920 - val_accuracy: 0.9789
# Epoch 9/20
# 382/382 [==============================] - 20s 51ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.0987 - val_accuracy: 0.9819
# Epoch 10/20
# 382/382 [==============================] - 19s 51ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.0883 - val_accuracy: 0.9811
# Epoch 11/20
# 382/382 [==============================] - 20s 52ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0925 - val_accuracy: 0.9809
# Epoch 12/20
# 382/382 [==============================] - 20s 51ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0982 - val_accuracy: 0.9796
# Epoch 13/20
# 382/382 [==============================] - 20s 52ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0995 - val_accuracy: 0.9801
# Epoch 14/20
# 382/382 [==============================] - 20s 53ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0978 - val_accuracy: 0.9826
# Epoch 15/20
# 382/382 [==============================] - 20s 52ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.1034 - val_accuracy: 0.9809
# Epoch 16/20
# 382/382 [==============================] - 20s 52ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1029 - val_accuracy: 0.9809
# Epoch 17/20
# 382/382 [==============================] - 21s 55ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1147 - val_accuracy: 0.9791
# Epoch 18/20
# 382/382 [==============================] - 17s 45ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1173 - val_accuracy: 0.9794
# Epoch 19/20
# 382/382 [==============================] - 17s 46ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1074 - val_accuracy: 0.9798
# Epoch 20/20
# 382/382 [==============================] - 16s 43ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.1092 - val_accuracy: 0.9810

# %%
plot_history([('M1-SkenarioBiLSTM02', history1)])

# %% [markdown]
# # Evaluasi 1

# %%
print("Evaluasi Data Test")
Y_act, Y_pred = evaluation(model1, X_test, label_test)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Test
# Accuracy: 98.17 %
# Precision: 98.22 %
# Recall: 98.03 %

# %%
print("Evaluasi Data Train")
Y_act, Y_pred = evaluation(model1, X_train, label_train)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Train
# Accuracy: 99.94 %
# Precision: 99.95 %
# Recall: 99.93 %

# %% [markdown]
# # Model 2

# %%
model2 = get_model2(X_train, Y_train)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 58, 128)           5300992
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 5,432,834
# Trainable params: 5,432,834
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training model
history2 = model2.fit(X_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/20
# 382/382 [==============================] - 52s 127ms/step - loss: 0.3855 - accuracy: 0.8024 - val_loss: 0.0655 - val_accuracy: 0.9826
# Epoch 2/20
# 382/382 [==============================] - 52s 136ms/step - loss: 0.0420 - accuracy: 0.9880 - val_loss: 0.0615 - val_accuracy: 0.9837
# Epoch 3/20
# 382/382 [==============================] - 61s 159ms/step - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.0834 - val_accuracy: 0.9753
# Epoch 4/20
# 382/382 [==============================] - 61s 160ms/step - loss: 0.0094 - accuracy: 0.9978 - val_loss: 0.0725 - val_accuracy: 0.9815
# Epoch 5/20
# 382/382 [==============================] - 61s 160ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.0895 - val_accuracy: 0.9806
# Epoch 6/20
# 382/382 [==============================] - 62s 161ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.0945 - val_accuracy: 0.9801
# Epoch 7/20
# 382/382 [==============================] - 62s 162ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.1111 - val_accuracy: 0.9764
# Epoch 8/20
# 382/382 [==============================] - 58s 152ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.0973 - val_accuracy: 0.9789
# Epoch 9/20
# 382/382 [==============================] - 48s 126ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.1082 - val_accuracy: 0.9779
# Epoch 10/20
# 382/382 [==============================] - 48s 127ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1040 - val_accuracy: 0.9784
# Epoch 11/20
# 382/382 [==============================] - 49s 128ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.1168 - val_accuracy: 0.9812
# Epoch 12/20
# 382/382 [==============================] - 48s 125ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.1134 - val_accuracy: 0.9762
# Epoch 13/20
# 382/382 [==============================] - 48s 125ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.1368 - val_accuracy: 0.9788
# Epoch 14/20
# 382/382 [==============================] - 48s 126ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.1216 - val_accuracy: 0.9788
# Epoch 15/20
# 382/382 [==============================] - 48s 126ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.1212 - val_accuracy: 0.9784
# Epoch 16/20
# 382/382 [==============================] - 62s 162ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1638 - val_accuracy: 0.9750
# Epoch 17/20
# 382/382 [==============================] - 62s 161ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.1362 - val_accuracy: 0.9788
# Epoch 18/20
# 382/382 [==============================] - 62s 162ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 0.1345 - val_accuracy: 0.9805
# Epoch 19/20
# 382/382 [==============================] - 63s 164ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.1214 - val_accuracy: 0.9775
# Epoch 20/20
# 382/382 [==============================] - 60s 156ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.1348 - val_accuracy: 0.9794

# %%
plot_history([('M2-SkenarioBiLSTM02', history2)])

# %% [markdown]
# # Evaluasi 2

# %%
print("Evaluasi Data Test")
Y_act, Y_pred = evaluation(model2, X_test, label_test)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Test
# Accuracy: 98.08 %
# Precision: 98.28 %
# Recall: 97.79 %

# %%
print("Evaluasi Data Train")
Y_act, Y_pred = evaluation(model2, X_train, label_train)
conf_matrix(Y_act, Y_pred)
# Out:
# Evaluasi Data Train
# Accuracy: 99.95 %
# Precision: 100.00 %
# Recall: 99.90 %

# %% [markdown]
# # Grafik Keseluruhan

# %%
plot_history([('M1-SkenarioBiLSTM02', history1),
              ('M2-SkenarioBiLSTM02', history2)])

# %% [markdown]
# # Save Model

# %%
model1.save('model/M1-SkenarioBiLSTM02.h5')
model2.save('model/M2-SkenarioBiLSTM02.h5')
